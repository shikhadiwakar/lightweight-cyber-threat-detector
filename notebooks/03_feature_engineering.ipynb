# %% [markdown]
# # Notebook 3 of 3 — Feature Engineering
#
# **Research Project:** Lightweight Machine Learning-Based Cybersecurity Threat Detection for Resource-Constrained Hardware
# **Author:** Anush Jindal
#
# **This is a skeleton, not a solved notebook — you write the code in the sections below.**
#
# Follow **`03_FEATURE_ENGINEERING_GUIDE.md`** (in this same folder) step by step. Each section heading here matches a step in that guide, with a short reminder of what goes there and an empty cell for your code. Do not skip ahead to training a model — that is intentionally the next stage, not this one.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
print("Libraries imported.")

# %% [markdown]
# ## Step 1 — Load your cleaned, split data from Notebook 2
#
# See guide Step 1. Load `X_train.csv`, `X_test.csv`, `y_train.csv`, `y_test.csv` — same `pd.read_csv` pattern you've used before. Adjust the paths to wherever you saved them at the end of `02_preprocessing.ipynb`.

# %%
# TODO: load X_train, X_test, y_train, y_test
# X_train = pd.read_csv("...")
# X_test = pd.read_csv("...")
# y_train = pd.read_csv("...")
# y_test = pd.read_csv("...")

# TODO: print the shapes and confirm they match what you recorded at the end of Notebook 2

# %% [markdown]
# ## Step 2 — Group your remaining features
#
# See guide Step 2. Sort every remaining column in `X_train` into groups such as traffic volume, connection behavior, packet characteristics, protocol, and port information — using the **actual column names you have**, not an assumed list.

# %%
# TODO: print X_train.columns and sort them into groups.
# feature_groups = {
#     "traffic_volume": [...],
#     "connection_behavior": [...],
#     "packet_characteristics": [...],
#     "protocol": [...],
#     "port_info": [...],
# }

# %% [markdown]
# ## Step 3 — Consider new engineered features (optional but should be a deliberate decision)
#
# See guide Step 3. If you create any new column, add it identically to both `X_train` and `X_test` using only information available within each row (never a statistic computed across the whole dataset).

# %%
# TODO: either engineer new feature(s) here, or write a short comment explaining
# why the existing columns are already sufficient.

# %% [markdown]
# ## Step 4 — Define the feature-selection experiment sets (A, B, C, D)
#
# See guide Step 4. Produce four lists of column names: a large set, a ~50% set, a "most important" set, and a very small set. You are only *defining* these lists here — training/scoring models against them is the next stage, not this notebook.

# %%
# TODO: build your four feature-set lists
# experiment_A_features = [...]  # large set
# experiment_B_features = [...]  # ~50%
# experiment_C_features = [...]  # most important, your judgment / a feature-selection method
# experiment_D_features = [...]  # very small set

# TODO: print len() of each list as a sanity check

# %% [markdown]
# ## Step 5 — Finish the feature documentation table
#
# See guide Step 5. This step happens in **`research/feature_documentation_template.md`**, not in this notebook — go fill it in now, then come back.

# %% [markdown]
# ## Step 6 — Save your engineered feature sets
#
# See guide Step 6. Save the final engineered `X_train`/`X_test` and your four feature-set lists so the next stage (baseline model — not part of this repo yet) can load them directly.

# %%
# TODO: save your engineered data and feature-set lists
# e.g. X_train.to_csv("X_train_engineered.csv", index=False)
#      X_test.to_csv("X_test_engineered.csv", index=False)
#      import json; json.dump({...}, open("feature_sets.json", "w"))

# %% [markdown]
# ## Stop here
#
# Do not train a Decision Tree (or any model) in this notebook. Once every checkbox in the guide's "When you're done" checklist is true, go fill in the corresponding items in `CHECKLIST.md` at the project root.
