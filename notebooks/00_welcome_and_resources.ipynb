# %% [markdown]
# # Welcome & Resources
#
# **Lightweight Cybersecurity Threat Detector** — start here in Colab.
#
# This notebook is the Colab-native version of `WELCOME.md` in the repo root: every tool
# you need, what it actually is, and every official link, in one place. The last cell
# runs a real environment check so you can confirm your Colab session has everything this
# project needs before you open the real work notebooks.

# %% [markdown]
# ## The 4 tools, and what each one actually is
#
# | Tool | What it is, in one line | Do you need to install it? |
# |---|---|---|
# | **Google Colab** | A free website that runs your Python code in the browser, on Google's computers | No install — just a browser and a Google login |
# | **GitHub** | A website that stores and backs up your project's code | No install — just a browser and a free account |
# | **Git** | The tool that saves versions of your code and talks to GitHub | Only if you edit files on your own PC (optional day-to-day) |
# | **Python** | The programming language everything is written in | Only needed locally if you install Git above — Colab already has Python built in |
#
# **Short version: for almost all of this project, all you need is a browser, a Google account, and a GitHub account.**

# %% [markdown]
# ## ⭐ Google Colab — official link
#
# **https://colab.research.google.com/**
#
# How to open this project's notebooks here:
# 1. Sign in with your Google account.
# 2. **File → Open notebook → GitHub tab**.
# 3. Paste: `shikhadiwakar/lightweight-cyber-threat-detector`
# 4. Open a notebook from the `notebooks/` folder.
# 5. Click **"Copy to Drive"** so your edits are actually saved.
# 6. To save progress back to the real project: **File → Save a copy in GitHub**.

# %% [markdown]
# ## GitHub — where the project lives
#
# - Create/sign in to an account: **https://github.com**
# - This project's repo: **https://github.com/shikhadiwakar/lightweight-cyber-threat-detector**
# - GitHub Docs — Getting Started: **https://docs.github.com/en/get-started**
#
# If you were invited as a collaborator, accept the invite from your email or GitHub notifications before trying to save changes to the repo.

# %% [markdown]
# ## Git & Python — only needed for local (non-Colab) work
#
# - Git: **https://git-scm.com/downloads**
# - Python: **https://www.python.org/downloads/** (tick "Add python.exe to PATH" on install)
# - VS Code (optional editor): **https://code.visualstudio.com/**
#
# The repo's `setup.bat` automates all of this locally on Windows; `SETUP_GUIDE.md` has the full manual walkthrough.

# %% [markdown]
# ## Python libraries used in this project (documentation)
#
# | Library | What it's for | Docs |
# |---|---|---|
# | pandas | Loading and manipulating tabular data | https://pandas.pydata.org/docs/ |
# | NumPy | Numerical arrays and math | https://numpy.org/doc/ |
# | scikit-learn | ML models and preprocessing | https://scikit-learn.org/stable/ |
# | Matplotlib | Plotting/graphs | https://matplotlib.org/stable/ |
# | Seaborn | Nicer statistical plots | https://seaborn.pydata.org/ |
# | Joblib | Saving/loading trained models | https://joblib.readthedocs.io/ |

# %% [markdown]
# ## Dataset
#
# | Resource | Link |
# |---|---|
# | CICIDS2017 official page (UNB / Canadian Institute for Cybersecurity) | https://www.unb.ca/cic/datasets/ids-2017.html |
# | CICIDS2017 mirror on Kaggle (individual day CSVs, includes proper headers) | https://www.kaggle.com/datasets/cicdataset/cicids2017 |
#
# See `data/README.md` in the repo for exactly which single file to start with and why.

# %% [markdown]
# ## Background reading
#
# | Topic | Resource |
# |---|---|
# | What is an Intrusion Detection System (IDS)? | https://en.wikipedia.org/wiki/Intrusion_detection_system |
# | Train/test split & data leakage | https://scikit-learn.org/stable/common_pitfalls.html |
# | Precision, Recall, F1 explained | https://scikit-learn.org/stable/modules/model_evaluation.html |
# | Decision Trees explained | https://scikit-learn.org/stable/modules/tree.html |
# | Feature selection (for Stage 4) | https://scikit-learn.org/stable/modules/feature_selection.html |
# | Markdown syntax | https://www.markdownguide.org/basic-syntax/ |
#
# The full categorized list (including later-stage tools like Streamlit/FastAPI/React you don't need yet) lives in `research/references.md`.

# %% [markdown]
# ## Environment check
#
# Run the cell below. If it prints "Environment ready" with no errors, this Colab session (or your local Python environment) has everything Notebooks 1-3 need.

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import sklearn
import joblib

print("Python:", sys.version.split()[0])
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", sns.__version__)
print("scikit-learn:", sklearn.__version__)
print("joblib:", joblib.__version__)
print("\nEnvironment ready — you can move on to notebooks/01_dataset_exploration.ipynb")
# Out:
# Python: 3.10.0
# pandas: 2.3.3
# numpy: 2.2.6
# matplotlib: 3.10.9
# seaborn: 0.13.2
# scikit-learn: 1.7.2
# joblib: 1.5.3
#
# Environment ready — you can move on to notebooks/01_dataset_exploration.ipynb

# %% [markdown]
# ## Next steps
#
# 1. `notebooks/01_dataset_exploration.ipynb` — load and inspect the dataset
# 2. `notebooks/02_preprocessing.ipynb` — clean it, split it safely
# 3. `notebooks/03_FEATURE_ENGINEERING_GUIDE.md` + `03_feature_engineering.ipynb` — you write this one
# 4. `CHECKLIST.md` — track what's actually done
#
# Full detail and troubleshooting for every step above: `SETUP_GUIDE.md`.
